# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

X = [[1],[2],[3],[4],[5]]
y = [2,3,np.nan,5,6]

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(X,y,'r--')
plt.show()

# %%
df = pd.DataFrame(X,y)
df['0'].fillna((df[df['0'].isna()-1]+df[df['0']+1].isna())/2)
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 df = pd.DataFrame(X,y)
# ----> 2 df['0'].fillna((df[df['0'].isna()-1]+df[df['0']+1].isna())/2)
#       3 print(df)
#
# File D:\Code\Phython\.venv\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File D:\Code\Phython\.venv\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: '0'
